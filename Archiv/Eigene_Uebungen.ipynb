# %% [markdown]
# Vom Nutzer die Größe und das Alter erfragen, um festlegen zu können ob er in der Achterbahn mitfahren kann.

# %%
height = int(input("Bitte gib deine Größe in cm ein: "))

if height > 150: 
    print("Du bist groß genug")
else :
    print("Du bist zu klein!")
# Out:
# Eingabe nicht erlaubt!!
# Du bist zu klein!
